# %% [markdown]
# ***Country Focus:***
#
#
#
# The United states generates the most revenue and has the most promising market among most countries.
#
# Recommendation:
#
#  The company should focus its marketing on the US market and other countries like Canada and France to further increase their influence and market size.

# %% [markdown]
# *Genre strategy:*
#
# Scifi& Fantasy is the most genre popular among customers.
#
# Recommendation:
#
# The company should focus on promoting its "Scifi & Fantasy" genre of  heavily due to its demand to increase revenue. Other promising genres like "Reggae & Pop" should also be considered for promotion.

# %% [markdown]
# *Customer* *strategy*:
#
# 10 customers (Helena Holy, Richard Cunningham,Luis Rojas,Hugh O'Riely, Ladislav Kovacs, Julia Barnett, Frank Ralston, Fynn zimmermann, Astrid Gruber and Victor Stevens)  stand out the most for making above average purchases from the company.
#
# Recommendation:
#
# These High-valued customers should be offered loyalty programs, exclusive offers and personalized recomendations to increase their lifetime value because of her high volume purchase from the company.

# %% [markdown]
# *Revenue Distribution:*
#
#
# Revenue appears to be concentrated among a small number of high-spending customers rather than evenly distributed across all customers.
#
# Recommendation:
#
# The company should retain relationship with high- value customers, while also implementing strategies to increase spending among low purchasing customers.

# %% [markdown]
# *Business Reccomendation*
#
#
# Based on the analysis, the company should focus on high-revenue countries such as the United States, promote top-performing genres like Rock, and implement customer retention strategies targeting high-spending customers. Additionally, expanding marketing efforts in emerging markets could help diversify revenue streams.
